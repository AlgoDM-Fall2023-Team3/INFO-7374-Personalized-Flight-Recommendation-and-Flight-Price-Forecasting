# %%
# !pip install databricks-sql
# Out:
# Collecting databricks-sql
#   Downloading databricks_sql-1.0.0-py3-none-any.whl (8.7 kB)
# Collecting databricks-sql-connector==2.2.1 (from databricks-sql)
#   Downloading databricks_sql_connector-2.2.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 4.0 MB/s eta 0:00:00
# Collecting pystache==0.6.0 (from databricks-sql)
#   Downloading pystache-0.6.0.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lz4<5.0.0,>=4.0.2 (from databricks-sql-connector==2.2.1->databricks-sql)
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.2 MB/s eta 0:00:00
# Collecting numpy==1.23.4 (from databricks-sql-connector==2.2.1->databricks-sql)
#   Downloading numpy-1.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-sql-connector==2.2.1->databricks-sql) (3.2.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from databricks-sql-connector==2.2.1->databricks-sql) (1.5.3)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from databricks-sql-connector==2.2.1->databricks-sql) (10.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.1 in /usr/local/lib/python3.10/dist-packages (from databricks-sql-connector==2.2.1->databricks-sql) (2.31.0)
# Collecting thrift<0.17.0,>=0.16.0 (from databricks-sql-connector==2.2.1->databricks-sql)
#   Downloading thrift-0.16.0.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.0->databricks-sql-connector==2.2.1->databricks-sql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.3.0->databricks-sql-connector==2.2.1->databricks-sql) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.1->databricks-sql-connector==2.2.1->databricks-sql) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.1->databricks-sql-connector==2.2.1->databricks-sql) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.1->databricks-sql-connector==2.2.1->databricks-sql) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.18.1->databricks-sql-connector==2.2.1->databricks-sql) (2023.11.17)
# Requirement already satisfied: six>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from thrift<0.17.0,>=0.16.0->databricks-sql-connector==2.2.1->databricks-sql) (1.16.0)
# Building wheels for collected packages: pystache, thrift
#   Building wheel for pystache (pyproject.toml) ... done
#   Created wheel for pystache: filename=pystache-0.6.0-py3-none-any.whl size=83618 sha256=4d225684bd3e17639b81b578cfcea7340d4e1516769e58e84d861f34ecb1472b
#   Stored in directory: /root/.cache/pip/wheels/4a/98/2c/84a50139380b5a5d8c0b4dfb92f2d860953c9e8e755507a402
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.16.0-cp310-cp310-linux_x86_64.whl size=373866 sha256=a55ae0a5a68e63524b34a4668bf2707cac9dfc77a39c5a8bf0b8ee8d7072552d
#   Stored in directory: /root/.cache/pip/wheels/52/f8/d2/acfd995e8247eb0cad372fa6a640a5fcf279ab2ed7c5c4490e
# Successfully built pystache thrift
# Installing collected packages: thrift, pystache, numpy, lz4, databricks-sql-connector, databricks-sql
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# tensorflow 2.14.0 requires numpy>=1.23.5, but you have numpy 1.23.4 which is incompatible.
# Successfully installed databricks-sql-1.0.0 databricks-sql-connector-2.2.1 lz4-4.3.2 numpy-1.23.4 pystache-0.6.0 thrift-0.16.0

# %% [markdown]
# Importing User Data

# %%
from databricks import sql
import pandas as pd

with sql.connect(server_hostname = "hostname",
                 http_path       = "http-path",
                 access_token    = "access-token") as connection:

  with connection.cursor() as cursor:
    cursor.execute("SELECT * FROM flight_recommendation.default.user")
    result = cursor.fetchall()
    user_data = pd.DataFrame(result)

# %%
user_data.columns = ['userid','name','age','email','phone_number','travel_purpose','flight_id','id']

# %%
user_data.head()
# Out:
#   userid           name age                      email    phone_number  \
# 0      1  Melissa Terry  22  jenniferwhite@example.com  +9749697939599
# 1      1  Melissa Terry  22  jenniferwhite@example.com  +9749697939599
# 2      1  Melissa Terry  22  jenniferwhite@example.com  +9749697939599
# 3      2   Aaron Harris  27        tyler31@example.org   +513359988596
# 4      2   Aaron Harris  27        tyler31@example.org   +513359988596
#
#   travel_purpose flight_id  id
# 0      Education      5826   0
# 1      Education      4661   1
# 2      Education      5281   2
# 3          Other      2131   3
# 4          Other      2479   4

# %%
user_data.shape
# Out:
# (9936, 8)

# %%
user_data['userid'] = user_data['userid'].astype(int)
user_data['flight_id'] = user_data['flight_id'].astype(int)

# %%
user_data.dtypes
# Out:
# userid             int64
# name              object
# age               object
# email             object
# phone_number      object
# travel_purpose    object
# flight_id          int64
# id                 int64
# dtype: object

# %% [markdown]
# Importing Flight Data

# %%
with sql.connect(server_hostname = "hostname",
                 http_path       = "http-path",
                 access_token    = "access-token") as connection:

  with connection.cursor() as cursor:
    cursor.execute("SELECT * FROM flight_recommendation.default.flight")
    result = cursor.fetchall()
    flight_data = pd.DataFrame(result)

# %%
flight_data.columns = ['id','_c0','to','from','date_to','date_from','pos_overall','url','type','price',
'airline','duration']

# %%
flight_data.dtypes
# Out:
# id               int64
# _c0             object
# to              object
# from            object
# date_to         object
# date_from       object
# pos_overall    float64
# url             object
# type            object
# price            int64
# airline         object
# duration        object
# dtype: object

# %%
flight_data['pos_overall'] = flight_data['pos_overall'].astype(float)

# %%
flight_data['price'] = flight_data['price'].astype(int)

# %%
flight_data.head()
# Out:
#    id _c0                          to                         from  \
# 0   0   0  Phoenix, AZ (all airports)  New York, NY (all airports)
# 1   1   1  Phoenix, AZ (all airports)  New York, NY (all airports)
# 2   2   2  Phoenix, AZ (all airports)  New York, NY (all airports)
# 3   3   3  Phoenix, AZ (all airports)  New York, NY (all airports)
# 4   4   4  Phoenix, AZ (all airports)  New York, NY (all airports)
#
#       date_to   date_from  pos_overall  \
# 0  2023-12-16  2023-12-10          1.0
# 1  2023-12-16  2023-12-10          1.0
# 2  2023-12-16  2023-12-10          1.0
# 3  2023-12-16  2023-12-10          1.0
# 4  2023-12-18  2023-12-11          1.0
#
#                                                  url        type price  \
# 0  https://www.google.com/travel/flights?sca_esv=...     Nonstop   258
# 1  https://www.google.com/travel/flights?sca_esv=...     Nonstop   358
# 2  https://www.google.com/travel/flights?sca_esv=...     Nonstop   358
# 3  https://www.google.com/travel/flights?sca_esv=...  Connecting   412
# 4  https://www.google.com/travel/flights?sca_esv=...     Nonstop   228
#
#     airline  duration
# 0    Spirit    5h 42m
# 1  American    5h 46m
# 2     Delta    5h 54m
# 3    Alaska  10h 15m+
# 4    Spirit    5h 42m

# %% [markdown]
# Importing Flight Popularity Data

# %%
with sql.connect(server_hostname = "hostname",
                 http_path       = "http-path",
                 access_token    = "access-token") as connection:

  with connection.cursor() as cursor:
    cursor.execute("SELECT * FROM flight_recommendation.default.flightpopularity")
    result = cursor.fetchall()
    data = pd.DataFrame(result)

# %%
data.columns = ['airline','popularity_score']

# %%
data.head()
# Out:
#     airline  popularity_score
# 0    Spirit              1375
# 1  American               784
# 2     Delta               544
# 3    Alaska               158
# 4   JetBlue               338

# %% [markdown]
# Recommend Flights to New User

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

def generate_recommendations_extended(flight_data, popularity_data, price_range,
                                      date_range,
                                      source, destination):
    # Assuming flight_data is a Pandas DataFrame with columns: 'id', 'airline', 'price', 'date', 'source', 'destination'
    # Convert the 'price' column to numeric values
       # Filter flights based on user inputs

    date_mask = (flight_data['date_from'] >= date_range[0]) & (flight_data['date_to'] <= date_range[1])
    source_dest_mask = ((flight_data['from'].str.contains(source)) & (flight_data['to'].str.contains(destination)))
    price_mask = (flight_data['price'] >= price_range[0]) & (flight_data['price'] <= price_range[1])

    filtered_data = flight_data[source_dest_mask & date_mask & price_mask]

    # Merge with popularity data and sort by popularity
    if not filtered_data.empty:
        recommendations = pd.merge(filtered_data, popularity_data, how='left', on='airline')
        #recommendations = recommendations[source_dest_mask]
        recommendations = recommendations.sort_values(by='popularity_score', ascending=False)

    return recommendations


# Example usage:
price_range = (300, 500)

date_range = ('2023-12-10', '2023-12-18')  # Adjust the date range as needed
source = 'New York'  # Replace with the actual source
destination = 'Los Angeles'  # Replace with the actual destination

result = generate_recommendations_extended(flight_data, data , price_range ,date_range,
                                             source, destination)
flight_result = pd.DataFrame(result)
flight_result
# Out:
#     id  _c0                     to                         from     date_to  \
# 2  357  379  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 4  361  383  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 5  362  384  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 0  352  374  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 1  356  378  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 3  360  382  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
#
#     date_from  pos_overall                                                url  \
# 2  2023-12-11          1.0  https://www.google.com/travel/flights?sca_esv=...
# 4  2023-12-12          1.0  https://www.google.com/travel/flights?sca_esv=...
# 5  2023-12-12          1.0  https://www.google.com/travel/flights?sca_esv=...
# 0  2023-12-10          1.0  https://www.google.com/travel/flights?sca_esv=...
# 1  2023-12-11          1.0  https://www.google.com/travel/flights?sca_esv=...
# 3  2023-12-12          1.0  https://www.google.com/travel/flights?sca_esv=...
#
#          type  price            airline  duration  popularity_score
# 2  Connecting    420             Spirit    1d 0h+            1375.0
# 4  Connecting    427             Spirit  18h 24m+            1375.0
# 5     Nonstop    438             Spirit    6h 16m            1375.0
# 0  Connecting    498  Multiple airlines    1d 2h+               NaN
# 1  Connecting    399  Multiple airlines    1d 0h+               NaN
# 3  Connecting    405  Multiple airlines  12h 33m+               NaN

# %% [markdown]
# #WORK FROM HERE

# %%
from sklearn.metrics.pairwise import cosine_similarity

def generate_flight_recommendations(user_id, flight_data, user_data, price_range, date_range, source, destination,top_k=3):
    # Merge flight and user data
    merged_data = pd.merge(flight_data, user_data, how='left', left_on='id', right_on='flight_id')

    merged_data['userid'] = merged_data['userid'].astype(float).fillna(0)
    merged_data['flight_id'] = merged_data['flight_id'].astype(float).fillna(0)
    merged_data['flight_id'] = merged_data['flight_id'].astype(int)

    # Filter flights for the given user
    user_flights = merged_data[merged_data['userid'] == user_id]

    # Create a user profile based on historical airlines
    user_profile = user_flights.groupby('airline').size().reset_index(name='num_trips')

    # Content-Based Filtering: Recommend flights based on historical airlines
    recommended_airlines = user_flights['airline'].value_counts().index[:top_k].tolist()

    # Get entire flight data for the recommended airlines
    recommended_flights_data = flight_data[flight_data['airline'].isin(recommended_airlines)]

    # Sort recommended flights based on the count of historical flights for each airline
    recommended_flights_data['airline_count'] = recommended_flights_data['airline'].map(user_profile.set_index('airline')['num_trips'])
    recommended_flights_data = recommended_flights_data.sort_values(by='airline_count', ascending=False).drop('airline_count', axis=1)

    date_mask = (recommended_flights_data['date_from'] >= date_range[0]) & (recommended_flights_data['date_to'] <= date_range[1])
    source_dest_mask = ((recommended_flights_data['from'].str.contains(source)) & (recommended_flights_data['to'].str.contains(destination)))

    price_mask = (recommended_flights_data['price'].astype(int) >= price_range[0]) & (recommended_flights_data['price'].astype(int) <= price_range[1])


    recommend_flight = recommended_flights_data[date_mask & price_mask & source_dest_mask]
    if recommend_flight.empty:
      date_mask = (flight_data['date_from'] >= date_range[0]) & (flight_data['date_to'] <= date_range[1])
      source_dest_mask = ((flight_data['from'].str.contains(source)) & (flight_data['to'].str.contains(destination)))

      price_mask = (flight_data['price'].astype(int) >= price_range[0]) & (flight_data['price'].astype(int) <= price_range[1])

      filtered_data = flight_data[date_mask & price_mask & source_dest_mask]
      return pd.DataFrame(filtered_data)
    else:

      # get all flights data
      date_mask = (flight_data['date_from'] >= date_range[0]) & (flight_data['date_to'] <= date_range[1])
      source_dest_mask = ((flight_data['from'].str.contains(source)) & (flight_data['to'].str.contains(destination)))

      price_mask = (flight_data['price'].astype(int) >= price_range[0]) & (flight_data['price'].astype(int) <= price_range[1])

      filtered_data_1 = flight_data[date_mask & price_mask & source_dest_mask]

      # get flights data from present in user history
      date_mask = (recommend_flight['date_from'] >= date_range[0]) & (recommend_flight['date_to'] <= date_range[1])
      source_dest_mask = ((recommend_flight['from'].str.contains(source)) & (recommend_flight['to'].str.contains(destination)))

      price_mask = (recommend_flight['price'].astype(int) >= price_range[0]) & (recommend_flight['price'].astype(int) <= price_range[1])

      filtered_data_2 = recommend_flight[date_mask & price_mask & source_dest_mask]

      filtered_data = pd.concat([filtered_data_1, filtered_data_2])
      filtered_data = filtered_data.drop_duplicates(subset=['id'])
      return pd.DataFrame(filtered_data)

# Example usage
user_id_to_recommend = 1
price_range = (0, 500)

date_range = ('2023-12-10', '2023-12-20')  # Adjust the date range as needed
source = 'New York'  # Replace with the actual source
destination = 'Los Angeles'  # Replace with the actual destination
recommended_flights_data = generate_flight_recommendations(user_id_to_recommend, flight_data, user_data,
                                                           price_range, date_range, source, destination)
print("Recommended Flights Data:")
recommended_flights_data
# Out:
# Recommended Flights Data:
# <ipython-input-32-cce306b120b7>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recommended_flights_data['airline_count'] = recommended_flights_data['airline'].map(user_profile.set_index('airline')['num_trips'])
#       id  _c0                     to                         from     date_to  \
# 352  352  374  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 356  356  378  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 357  357  379  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 360  360  382  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 361  361  383  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 362  362  384  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-18
# 364  364  386  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-19
# 365  365  387  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-19
# 366  366  388  Los Angeles, CA (LAX)  New York, NY (all airports)  2023-12-19
#
#       date_from  pos_overall  \
# 352  2023-12-10          1.0
# 356  2023-12-11          1.0
# 357  2023-12-11          1.0
# 360  2023-12-12          1.0
# 361  2023-12-12          1.0
# 362  2023-12-12          1.0
# 364  2023-12-13          1.0
# 365  2023-12-13          1.0
# 366  2023-12-13          1.0
#
#                                                    url        type  price  \
# 352  https://www.google.com/travel/flights?sca_esv=...  Connecting    498
# 356  https://www.google.com/travel/flights?sca_esv=...  Connecting    399
# 357  https://www.google.com/travel/flights?sca_esv=...  Connecting    420
# 360  https://www.google.com/travel/flights?sca_esv=...  Connecting    405
# 361  https://www.google.com/travel/flights?sca_esv=...  Connecting    427
# 362  https://www.google.com/travel/flights?sca_esv=...     Nonstop    438
# 364  https://www.google.com/travel/flights?sca_esv=...  Connecting    375
# 365  https://www.google.com/travel/flights?sca_esv=...  Connecting    403
# 366  https://www.google.com/travel/flights?sca_esv=...     Nonstop    478
#
#                airline  duration
# 352  Multiple airlines    1d 2h+
# 356  Multiple airlines    1d 0h+
# 357             Spirit    1d 0h+
# 360  Multiple airlines  12h 33m+
# 361             Spirit  18h 24m+
# 362             Spirit    6h 16m
# 364  Multiple airlines   9h 35m+
# 365             Spirit   9h 35m+
# 366             Spirit    6h 16m
